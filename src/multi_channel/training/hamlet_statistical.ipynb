# %% [markdown]
# # Intro
#
# This calculates the following statistics about the dataset:
#
# 1. Cardinality of the dataset (mean number of labels per pixel)
# 2. Density (mean number of labels per pixel/number of labels in the dataset)
# 3. Single label pixels (percentage of pixels in the dataset with only one active label)
# 4. Frequency of each label per image
# 5. Frequency of each label per pixel
# 6. Imbalance ratio for each label (# time the most frequent label appears/# of times the
# label of interest appears)
# 7. Mean imbalance ratio
#
# The results can be seen in Table 4 in the MultiSolSegment paper

# %% [markdown]
# ## setup

# %%
import numpy as np
import os
from collections import Counter

# %%
root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_Combined_CWRU_LBNL_ASU/"

img_folder = root + "img/all/"
mask_folder = root + "ann/all/"

# image_file_extension = "tiff"
# image_file_extension = "jpg"

category_mapping = {0: "empty", 1: "dark", 2: "busbar", 3: "crack", 4: "non-cell"}
categories_list = list(category_mapping.values())

# %%
files = [c for c in os.listdir(mask_folder)]
n_masks = len(files)

# regex_string = r'(.+)\.' + image_file_extension + r'\.json'

# n_masks = [re.search(regex_string, f).group(1) for f in files]

# %% [markdown]
# -----

# %% [markdown]
# ## class information

# %%
files
# Out:
# ['mx_SW2-DH3000-500h-PT-cell54-flr.npy',
#  'SW3-DH3000-1500h-PT-cell44-r180.npy',
#  'mxy_2002.npy',
#  'mxy_0601.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell46-r180.npy',
#  'mxy_SW1-DH3000-500h-PT-cell50-flr.npy',
#  'mx_1217 - Old TC for PID_2_front_Isc (EL Image).npy',
#  'my_SW1-DH3000-1500h-PT-cell56.npy',
#  '1_EL_18.09.2023-15-40-40_unknownID_ASU Minisample_SHJ5_103.npy',
#  'mxy_sa19976_sub_EL_9-c04.npy',
#  'mxy_sa19958_sub_EL_9-c02.npy',
#  'mxy_sa19966_sub_EL_9-c02.npy',
#  'mx_SW1-DH3000-2000h-PT-cell37.npy',
#  'mxy_sa19990_sub_EL_9-c04.npy',
#  'mx_3_EL_18.09.2023-15-00-34_unknownID_ASU Minisample_07_68.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell37-flr.npy',
#  'SW2-DH3000-1500h-PT-cell54-flr.npy',
#  'mxy_sa19979_sub_EL_9-c03.npy',
#  'mxy_sa19980_sub_EL_9-c02.npy',
#  'mx_SW2-DH3000-500h-PT-cell54-fup.npy',
#  'my_SW3-DH3000-2000h-PT-cell37-r180.npy',
#  '1240 - NICE_SHJ_2_Isc (EL Image).npy',
#  'SW1-DH3000-1500h-PT-cell49-flr.npy',
#  'mx_SW3-DH3000-2000h-PT-cell42-flr.npy',
#  'mx_sa19958_sub_EL_9-c04.npy',
#  'my_sa19959_sub_EL_9-c02.npy',
#  'mx_sa19976_sub_EL_9-c02.npy',
#  'sa19961_sub_EL_9-c04.npy',
#  'sa19971_sub_EL_9-c02.npy',
#  'my_sa19967_sub_EL_9-c02.npy',
#  'mx_sa19969_sub_EL_9-c03.npy',
#  'my_sa19991_sub_EL_9-c04.npy',
#  'mx_sa19990_sub_EL_9-c02.npy',
#  'mxy_1090.npy',
#  'SW2-DH3000-1500h-PT-cell54-fup.npy',
#  'mx_sa19980_sub_EL_9-c04.npy',
#  'my_sa19978_sub_EL_9-c03.npy',
#  '1220 - Old TC for PID_2_rear_Isc (EL Image).npy',
#  'sa19997_sub_EL_9-c02.npy',
#  'SW3-DH3000-1500h-PT-cell37.npy',
#  'SW1-DH3000-500h-PT-cell37-r180.npy',
#  '0634.npy',
#  'mxy_0563.npy',
#  'my_SW1-DH3000-1500h-PT-cell50-flr.npy',
#  'mx_1529.npy',
#  'my_1529.npy',
#  'my_0179.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell19.npy',
#  'my_SW2-DH3000-1000h-PT-cell59-r180.npy',
#  'SW2-DH3000-1000h-PT-cell19-fup.npy',
#  'my_1302 - NICE TOPCon 2 Front Enapsulated (EL Image).npy',
#  '3_EL_18.09.2023-15-43-19_unknownID_ASU Minisample_SHJ6_106.npy',
#  'mx_0179.npy',
#  'my_1298.npy',
#  'my_1240 - NICE_SHJ_2_Isc (EL Image).npy',
#  'mx_1298.npy',
#  'mx_SW2-DH3000-1500h-PT-cell57-fup.npy',
#  '0026.npy',
#  'mx_SW1-DH3000-1500h-PT-cell34.npy',
#  'my_0_EL_2x2_NQ-03_20230915_125152.jpg.npy',
#  'my_SW1-DH3000-1500h-PT-cell50-fup.npy',
#  'mx_1224 - Old TC for PID_3_front_Isc (EL Image).jpg.npy',
#  'mx_SW2-DH3000-1500h-PT-cell59.npy',
#  'my_LG2-DH3000-1000h-PT-cell24-flr.npy',
#  'mx_SW3-DH3000-1000h-PT-cell42-r180.npy',
#  'mxy_SW3-DH3000-500h-PT-cell12-r180.npy',
#  'SW2-DH3000-1500h-PT-cell46.npy',
#  'SW1-DH3000-500h-PT-cell43.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell10-flr.npy',
#  'mx_SW1-DH3000-500h-PT-cell15-fup.npy',
#  'mx_LG2-DH3000-500h-PT-cell24-r180.npy',
#  'mxy_1207 - Old TC for PID_1_front_Isc (EL Image).npy',
#  '0556.npy',
#  'mx_SW2-DH3000-1500h-PT-cell57-flr.npy',
#  'mx_SW1-DH3000-1000h-PT-cell37-r180.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell12.npy',
#  'sa19983_sub_EL_9-c01.npy',
#  'my_sa19995_sub_EL_9-c01.npy',
#  'mx_sa19984_sub_EL_9-c01.npy',
#  'SW1-DH3000-2000h-PT-cell54-r180.npy',
#  'SW1-DH3000-2000h-PT-cell34-flr.npy',
#  'my_1931.npy',
#  'mx_1_EL_18.09.2023-15-53-07_unknownID_ASU Minisample_SHJ8_117.npy',
#  'my_sa19973_sub_EL_9-c01.npy',
#  'mx_1931.npy',
#  'LG2-DH3000-500h-PT-cell24-fup.npy',
#  'sa19965_sub_EL_9-c01.npy',
#  'mx_sa19962_sub_EL_9-c01.npy',
#  '1852.npy',
#  'SW3-DH3000-1000h-PT-cell50.npy',
#  'mxy_0774.npy',
#  '2_EL_2x2_NQ-03_20230915_125152.npy',
#  'mxy_1318.npy',
#  'mxy_-1_EL_18.09.2023-15-53-07_unknownID_ASU Minisample_SHJ8_117.npy',
#  'SW2-DH3000-1000h-PT-cell54-flr.npy',
#  'my_1152 - Ea_SHJ_POE_4_Isc (EL Image).npy',
#  'mxy_sa19994_sub_EL_9-c01.npy',
#  'my_SW1-DH3000-2000h-PT-cell54.npy',
#  'SW1-DH3000-1000h-PT-cell49-fup.npy',
#  'LG2-DH3000-500h-PT-cell24-flr.npy',
#  'mxy_sa19972_sub_EL_9-c01.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell18-flr.npy',
#  'mx_0_EL_2x2_NQ-04_20230915_130134.npy',
#  'mxy_1867.npy',
#  'mx_SW2-DH3000-1000h-PT-cell46-r180.npy',
#  'mxy_1654.npy',
#  'my_SW1-DH3000-1000h-PT-cell19.npy',
#  'my_2021.npy',
#  'mxy_1668.npy',
#  '3_EL_2x2_NQ-01_20230915_125923.npy',
#  'mx_2021.npy',
#  'mxy_1179 - Ea_TC_EVA_2_Isc (EL Image).npy',
#  'mx_SW1-DH3000-2000h-PT-cell37-fup.npy',
#  'mx_sa19990_sub_EL_9-c03.npy',
#  'sa19997_sub_EL_9-c03.npy',
#  'mx_sa19979_sub_EL_9-c04.npy',
#  'my_sa19978_sub_EL_9-c02.npy',
#  'mx_3_EL_18.09.2023-15-34-42_unknownID_ASU Minisample_SHJ3_97.npy',
#  'mx_sa19976_sub_EL_9-c03.npy',
#  'my_sa19959_sub_EL_9-c03.npy',
#  'my_sa19967_sub_EL_9-c03.npy',
#  'sa19971_sub_EL_9-c03.npy',
#  'sa19988_sub_EL_9-c02.npy',
#  'my_SW1-DH3000-500h-PT-cell52-flr.npy',
#  'mxy_SW3-DH3000-500h-PT-cell12-fup.npy',
#  'mx_SW2-DH3000-500h-PT-cell19-flr.npy',
#  'mxy_1046.npy',
#  'SW2-DH3000-1500h-PT-cell19-flr.npy',
#  'my_1460.npy',
#  'mx_1460.npy',
#  'my_SW1-DH3000-1000h-PT-cell50-fup.npy',
#  'SW1-DH3000-2000h-PT-cell56-fup.npy',
#  '1155 - Ea_SHJ_POE_5_Isc (EL Image).npy',
#  'mxy_sa19980_sub_EL_9-c03.npy',
#  'mxy_sa19979_sub_EL_9-c02.npy',
#  'mx_SW2-DH3000-1000h-PT-cell57-fup.npy',
#  'my_SW1-DH3000-500h-PT-cell52-fup.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell10-fup.npy',
#  '1073.npy',
#  'mx_SW1-DH3000-500h-PT-cell9.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell10-r180.npy',
#  'mxy_sa19958_sub_EL_9-c03.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell56.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell52-fup.npy',
#  'mxy_sa19966_sub_EL_9-c03.npy',
#  '1182 - Ea_TC_EVA_3_Isc (EL Image).npy',
#  'mxy_SW1-DH3000-2000h-PT-cell33.npy',
#  'my_3_EL_18.09.2023-14-51-50_unknownID_ASU Minisample_05_57.npy',
#  'my_LG2-DH3000-1500h-PT-cell24-fup.npy',
#  '0392.npy',
#  'SW1-DH3000-1000h-PT-cell49-r180.npy',
#  'mx_LG2-DH3000-1500h-PT-cell24.npy',
#  'my_0540.npy',
#  'SW1-DH3000-2000h-PT-cell15.npy',
#  'mx_0540.npy',
#  'my_SW1-DH3000-500h-PT-cell54.npy',
#  'my_2_EL_18.09.2023-14-45-47_unknownID_ASU Minisample_09_51.npy',
#  'my_SW1-DH3000-1500h-PT-cell49-flr.npy',
#  'mx_0556.npy',
#  'mxy_1_EL_2x2_NQ-02_20230915_130525.npy',
#  'mx_SW3-DH3000-1000h-PT-cell44-flr.npy',
#  'my_0556.npy',
#  'my_SW2-DH3000-1500h-PT-cell54-fup.npy',
#  'mx_2_EL_18.09.2023-15-27-31_unknownID_ASU Minisample_SHJ1_91.npy',
#  'mxy_SW3-DH3000-1000h-PT-cell50-r180.npy',
#  'my_SW1-DH3000-500h-PT-cell37-r180.npy',
#  'mxy_sa19966_sub_EL_9-c01.npy',
#  'mx_SW1-DH3000-2000h-PT-cell9-r180.npy',
#  'mxy_sa19958_sub_EL_9-c01.npy',
#  'my_SW2-DH3000-500h-PT-cell57-flr.npy',
#  'mxy_sa19980_sub_EL_9-c01.npy',
#  '3_EL_18.09.2023-14-55-55_unknownID_ASU Minisample_06_62.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell9.npy',
#  'my_0026.npy',
#  'mx_0026.npy',
#  '1298.npy',
#  'my_SW2-DH3000-1500h-PT-cell54-flr.npy',
#  'sa19971_sub_EL_9-c01.npy',
#  'mx_sa19976_sub_EL_9-c01.npy',
#  'my_sa19959_sub_EL_9-c01.npy',
#  'mx_SW1-DH3000-1500h-PT-cell43-fup.npy',
#  'my_SW2-DH3000-500h-PT-cell57-fup.npy',
#  '0179.npy',
#  'mxy_2_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_03_48.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell19-flr.npy',
#  'mx_SW1-DH3000-1500h-PT-cell33-r180.npy',
#  'mxy_SW2-DH3000-1000h-PT-cell14-fup.npy',
#  '1529.npy',
#  'mx_SW1-DH3000-500h-PT-cell37.npy',
#  'sa19997_sub_EL_9-c01.npy',
#  'mx_sa19990_sub_EL_9-c01.npy',
#  'my_SW1-DH3000-1000h-PT-cell33.npy',
#  'my_0634.npy',
#  'mx_SW2-DH3000-500h-PT-cell54-r180.npy',
#  'mx_0634.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell54-flr.npy',
#  'mxy_SW2-DH3000-1500h-PT-cell59-fup.npy',
#  'mxy_SW1-DH3000-500h-PT-cell49-flr.npy',
#  'mxy_sa19972_sub_EL_9-c03.npy',
#  'mxy_SW3-DH3000-1000h-PT-cell18-r180.npy',
#  'my_0_EL_18.09.2023-15-00-34_unknownID_ASU Minisample_07_68.npy',
#  '1227 - Old TC for PID_3_rear_Isc (EL Image).npy',
#  'SW1-DH3000-1500h-PT-cell50-fup.npy',
#  'mx_2_EL_18.09.2023-15-37-22_unknownID_ASU Minisample_SHJ4_100.npy',
#  'my_SW2-DH3000-1500h-PT-cell14-r180.npy',
#  'LG2-DH3000-1000h-PT-cell24-flr.npy',
#  'mxy_1_EL_18.09.2023-15-37-22_unknownID_ASU Minisample_SHJ4_100.npy',
#  'mxy_sa19994_sub_EL_9-c03.npy',
#  'my_SW1-DH3000-2000h-PT-cell49-r180.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell54-fup.npy',
#  'mxy_SW3-DH3000-500h-PT-cell46-flr.npy',
#  'mxy_0762.npy',
#  'SW3-DH3000-1000h-PT-cell46.npy',
#  'SW1-DH3000-1500h-PT-cell50-flr.npy',
#  'SW1-DH3000-500h-PT-cell54.npy',
#  '1_EL_18.09.2023-15-03-23_unknownID_ASU Minisample_08_71.npy',
#  'SW3-DH3000-2000h-PT-cell37.npy',
#  'mx_sa19962_sub_EL_9-c03.npy',
#  'mx_SW2-DH3000-500h-PT-cell59.npy',
#  'sa19965_sub_EL_9-c03.npy',
#  'my_sa19973_sub_EL_9-c03.npy',
#  'mx_sa19984_sub_EL_9-c03.npy',
#  'my_sa19995_sub_EL_9-c03.npy',
#  'my_SW2-DH3000-1000h-PT-cell19-fup.npy',
#  'sa19983_sub_EL_9-c03.npy',
#  'my_SW3-DH3000-500h-PT-cell44-fup.npy',
#  'mxy_0_EL_18.09.2023-15-03-23_unknownID_ASU Minisample_08_71.npy',
#  'my_sa19985_sub_EL_9-c04.npy',
#  'mx_sa19984_sub_EL_9-c02.npy',
#  'sa19993_sub_EL_9-c04.npy',
#  'mx_SW1-DH3000-500h-PT-cell33-fup.npy',
#  'sa19983_sub_EL_9-c02.npy',
#  'my_sa19995_sub_EL_9-c02.npy',
#  'mx_sa19994_sub_EL_9-c04.npy',
#  '0540.npy',
#  'mx_0392.npy',
#  'my_sa19963_sub_EL_9-c04.npy',
#  'mx_sa19962_sub_EL_9-c02.npy',
#  'my_sa19973_sub_EL_9-c02.npy',
#  'mx_sa19972_sub_EL_9-c04.npy',
#  'SW3-DH3000-1000h-PT-cell37-r180.npy',
#  'sa19965_sub_EL_9-c02.npy',
#  'my_0392.npy',
#  'my_3_EL_2x2_NQ-01_20230915_125923.npy',
#  'mx_SW1-DH3000-1000h-PT-cell43-fup.npy',
#  'mxy_0987.npy',
#  'mx_1073.npy',
#  '1243 - NICE_TC_Old_Post_Isc (EL Image).npy',
#  'my_SW2-DH3000-1000h-PT-cell54-flr.npy',
#  'my_1073.npy',
#  'mxy_1455.npy',
#  'my_SW1-DH3000-1000h-PT-cell49-fup.npy',
#  'mx_SW3-DH3000-1500h-PT-cell44-fup.npy',
#  'mxy_SW2-DH3000-2000h-PT-cell46-flr.npy',
#  'my_1_EL_18.09.2023-15-43-19_unknownID_ASU Minisample_SHJ6_106.npy',
#  'mxy_SW2-DH3000-1500h-PT-cell14-flr.npy',
#  'mxy_sa19984_sub_EL_9-c04.npy',
#  'mx_SW1-DH3000-500h-PT-cell33-flr.npy',
#  'mxy_sa19994_sub_EL_9-c02.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell15-r180.npy',
#  'mx_SW1-DH3000-500h-PT-cell50-r180.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell9-flr.npy',
#  'my_SW3-DH3000-500h-PT-cell44-flr.npy',
#  'my_SW1-DH3000-2000h-PT-cell43.npy',
#  '1_EL_2x2_NQ-01_20230915_125923.jpg.npy',
#  'my_2_EL_2x2_NQ-03_20230915_125152.npy',
#  'mx_SW1-DH3000-1000h-PT-cell43-flr.npy',
#  '1460.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell19-fup.npy',
#  'my_1166 - Ea_SHJ_EVA_3_Isc (EL Image).npy',
#  'mxy_sa19972_sub_EL_9-c02.npy',
#  'mx_1_EL_18.09.2023-14-45-47_unknownID_ASU Minisample_09_51.npy',
#  'my_SW1-DH3000-2000h-PT-cell34-flr.npy',
#  'mxy_1240 - NICE_SHJ_2_Isc (EL Image).npy',
#  'mx_SW3-DH3000-500h-PT-cell44-r180.npy',
#  'mx_SW1-DH3000-2000h-PT-cell56-r180.npy',
#  'mxy_2_EL_18.09.2023-14-38-10_unknownID_ASU Minisample_02_43.npy',
#  'my_0_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_04_48.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell33.npy',
#  'my_sa19978_sub_EL_9-c01.npy',
#  'LG2-DH3000-1500h-PT-cell24-fup.npy',
#  'mx_sa19969_sub_EL_9-c01.npy',
#  '2021.npy',
#  'mxy_1938.npy',
#  '3_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_03_48.npy',
#  'mxy_1904.npy',
#  'sa19988_sub_EL_9-c01.npy',
#  'mxy_SW2-DH3000-1000h-PT-cell59-flr.npy',
#  'mxy_1737.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell54-fup.npy',
#  'my_SW2-DH3000-1500h-PT-cell19-flr.npy',
#  'mxy_sa19979_sub_EL_9-c01.npy',
#  'SW2-DH3000-2000h-PT-cell59-r180.npy',
#  'SW1-DH3000-1000h-PT-cell50-fup.npy',
#  'mxy_2_EL_18.09.2023-14-55-55_unknownID_ASU Minisample_06_62.npy',
#  'my_SW1-DH3000-2000h-PT-cell56-fup.npy',
#  'my_1852.npy',
#  'mx_1852.npy',
#  'mx_SW2-DH3000-2000h-PT-cell19-r180.npy',
#  'mx_SW1-DH3000-1000h-PT-cell50.npy',
#  '1931.npy',
#  'my_3_EL_18.09.2023-15-40-40_unknownID_ASU Minisample_SHJ5_103.npy',
#  'my_SW1-DH3000-500h-PT-cell43.npy',
#  'mx_SW1-DH3000-500h-PT-cell19-r180.npy',
#  'mxy_SW1-DH3000-500h-PT-cell10-r180.npy',
#  'SW1-DH3000-1500h-PT-cell33-fup.npy',
#  '0_EL_18.09.2023-15-03-23_unknownID_ASU Minisample_08_71.npy',
#  'mxy_1_EL_2x2_NQ-04_20230915_130134.npy',
#  'mxy_sa19969_sub_EL_9-c03.npy',
#  'mxy_sa19990_sub_EL_9-c02.npy',
#  'mxy_sa19980_sub_EL_9-c04.npy',
#  '1048.npy',
#  'my_SW1-DH3000-2000h-PT-cell9.npy',
#  'mx_SW1-DH3000-1500h-PT-cell52-fup.npy',
#  'mx_SW1-DH3000-2000h-PT-cell10-fup.npy',
#  'my_SW1-DH3000-1500h-PT-cell50.npy',
#  'mxy_sa19958_sub_EL_9-c04.npy',
#  'mxy_sa19976_sub_EL_9-c02.npy',
#  '0418.npy',
#  '1289.npy',
#  'my_1467.npy',
#  'my_1_EL_18.09.2023-15-00-34_unknownID_ASU Minisample_07_68.npy',
#  'mx_1467.npy',
#  '1148 - Ea_SHJ_POE_3_Isc (EL Image).npy',
#  'mxy_SW3-DH3000-1500h-PT-cell42-r180.npy',
#  'my_SW3-DH3000-500h-PT-cell18.npy',
#  'mx_sa19990_sub_EL_9-c04.npy',
#  'mxy_SW2-DH3000-500h-PT-cell19-flr.npy',
#  'my_sa19991_sub_EL_9-c02.npy',
#  'mx_SW3-DH3000-500h-PT-cell12-fup.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell37-fup.npy',
#  'my_SW1-DH3000-1000h-PT-cell49-r180.npy',
#  'mx_sa19979_sub_EL_9-c03.npy',
#  'mx_sa19980_sub_EL_9-c02.npy',
#  'sa19997_sub_EL_9-c04.npy',
#  'mx_sa19976_sub_EL_9-c04.npy',
#  'my_sa19959_sub_EL_9-c04.npy',
#  'mx_sa19958_sub_EL_9-c02.npy',
#  '1224 - Old TC for PID_3_front_Isc (EL Image).jpg.npy',
#  'sa19961_sub_EL_9-c02.npy',
#  '2_EL_18.09.2023-14-38-10_unknownID_ASU Minisample_02_43.npy',
#  'sa19971_sub_EL_9-c04.npy',
#  'mx_sa19966_sub_EL_9-c02.npy',
#  'my_sa19967_sub_EL_9-c04.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell18-r180.npy',
#  'my_SW2-DH3000-500h-PT-cell46-flr.npy',
#  '1504.npy',
#  'mx_1303 - NICE TOPCon 1 Front Enapsulated (EL Image).npy',
#  'my_1275.npy',
#  'my_SW3-DH3000-500h-PT-cell18-flr.npy',
#  'mxy_3_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_03_48.npy',
#  'mx_1275.npy',
#  '0949.npy',
#  'my_SW1-DH3000-2000h-PT-cell54-r180.npy',
#  'my_1249.npy',
#  'mx_1249.npy',
#  'my_0194.npy',
#  'my_SW1-DH3000-1000h-PT-cell15-flr.npy',
#  'mxy_SW3-DH3000-1000h-PT-cell42-fup.npy',
#  'mx_1_EL_18.09.2023-15-37-22_unknownID_ASU Minisample_SHJ4_100.npy',
#  'mx_0194.npy',
#  'mx_SW3-DH3000-1500h-PT-cell18-flr.npy',
#  'mxy_2_EL_18.09.2023-15-37-22_unknownID_ASU Minisample_SHJ4_100.npy',
#  'my_0369.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell50-r180.npy',
#  '1855.npy',
#  'mx_0369.npy',
#  'my_SW3-DH3000-2000h-PT-cell50-fup.npy',
#  '2_EL_18.09.2023-14-55-55_unknownID_ASU Minisample_06_62.npy',
#  'my_SW3-DH3000-1500h-PT-cell12-fup.npy',
#  'SW3-DH3000-1000h-PT-cell46-fup.npy',
#  'mx_1_EL_18.09.2023-15-34-42_unknownID_ASU Minisample_SHJ3_97.npy',
#  '1869.npy',
#  'mx_SW3-DH3000-1000h-PT-cell37-fup.npy',
#  'SW2-DH3000-1500h-PT-cell54.npy',
#  'mx_SW3-DH3000-1500h-PT-cell12-r180.npy',
#  'mx_sa19972_sub_EL_9-c01.npy',
#  'mx_SW1-DH3000-1000h-PT-cell52-flr.npy',
#  'my_sa19963_sub_EL_9-c01.npy',
#  'SW1-DH3000-500h-PT-cell50.npy',
#  'mxy_SW2-DH3000-2000h-PT-cell57-flr.npy',
#  '1883.npy',
#  'SW3-DH3000-500h-PT-cell42-r180.npy',
#  'mx_sa19994_sub_EL_9-c01.npy',
#  'my_sa19985_sub_EL_9-c01.npy',
#  'SW2-DH3000-1000h-PT-cell59-r180.npy',
#  'sa19993_sub_EL_9-c01.npy',
#  'mxy_SW1-DH3000-500h-PT-cell15-fup.npy',
#  'SW1-DH3000-500h-PT-cell56-r180.npy',
#  'mxy_3_EL_18.09.2023-14-55-55_unknownID_ASU Minisample_06_62.npy',
#  'mx_SW2-DH3000-1000h-PT-cell19-r180.npy',
#  'SW1-DH3000-1000h-PT-cell33-flr.npy',
#  '1471.npy',
#  'mxy_sa19962_sub_EL_9-c01.npy',
#  'my_SW1-DH3000-2000h-PT-cell52.npy',
#  'mxy_sa19984_sub_EL_9-c01.npy',
#  'mx_SW1-DH3000-1500h-PT-cell33.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell37-flr.npy',
#  '0021.npy',
#  'mx_LG2-DH3000-1500h-PT-cell24-r180.npy',
#  'my_SW2-DH3000-500h-PT-cell14.npy',
#  '2_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_03_48.npy',
#  'mxy_0558.npy',
#  'mxy_1134.npy',
#  'SW1-DH3000-1500h-PT-cell10.npy',
#  'mx_0_EL_18.09.2023-14-45-47_unknownID_ASU Minisample_09_51.npy',
#  'mxy_SW3-DH3000-1500h-PT-cell42-flr.npy',
#  'SW3-DH3000-1500h-PT-cell18.npy',
#  'my_SW1-DH3000-1500h-PT-cell15-fup.npy',
#  'sa19961_sub_EL_9-c03.npy',
#  'mx_sa19958_sub_EL_9-c03.npy',
#  'mx_sa19966_sub_EL_9-c03.npy',
#  'mx_SW3-DH3000-1000h-PT-cell18-fup.npy',
#  'my_SW3-DH3000-1500h-PT-cell44-r180.npy',
#  'sa19988_sub_EL_9-c04.npy',
#  'my_sa19991_sub_EL_9-c03.npy',
#  'mxy_1227 - Old TC for PID_3_rear_Isc (EL Image).npy',
#  'mx_sa19980_sub_EL_9-c03.npy',
#  'my_sa19978_sub_EL_9-c04.npy',
#  'mx_sa19979_sub_EL_9-c02.npy',
#  'mx_0963.npy',
#  'mxy_1097.npy',
#  'mx_SW3-DH3000-1500h-PT-cell37-fup.npy',
#  'mx_1_EL_18.09.2023-14-51-50_unknownID_ASU Minisample_05_57.npy',
#  'my_0963.npy',
#  '0633.npy',
#  'my_1_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_04_48.npy',
#  '0800.npy',
#  'my_3_EL_2x2_NQ-04_20230915_130134.npy',
#  'my_1212 - Old TC for PID_1_rear_Isc (EL Image).jpg.npy',
#  'mx_1300.npy',
#  'my_1300.npy',
#  'mxy_SW2-DH3000-500h-PT-cell54-fup.npy',
#  'mxy_sa19976_sub_EL_9-c03.npy',
#  'SW3-DH3000-2000h-PT-cell37-r180.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell50.npy',
#  'mxy_0809.npy',
#  'mx_SW3-DH3000-500h-PT-cell50.npy',
#  'my_0591.npy',
#  'mx_SW3-DH3000-500h-PT-cell44.npy',
#  'mx_0591.npy',
#  'mxy_SW2-DH3000-500h-PT-cell14-r180.npy',
#  '0343.npy',
#  'mx_SW3-DH3000-1500h-PT-cell37-flr.npy',
#  'mxy_sa19990_sub_EL_9-c03.npy',
#  'mxy_sa19979_sub_EL_9-c04.npy',
#  'mx_1240 - NICE_SHJ_2_Isc (EL Image).npy',
#  'my_SW1-DH3000-500h-PT-cell52.npy',
#  'mxy_1_EL_18.09.2023-15-03-23_unknownID_ASU Minisample_08_71.npy',
#  'mx_0220.npy',
#  'mxy_SW2-DH3000-1500h-PT-cell46-r180.npy',
#  'SW3-DH3000-1500h-PT-cell46-flr.npy',
#  'mx_SW1-DH3000-500h-PT-cell50-flr.npy',
#  'my_SW3-DH3000-1000h-PT-cell12-flr.npy',
#  'my_SW3-DH3000-500h-PT-cell37-flr.npy',
#  'my_0220.npy',
#  'mxy_SW2-DH3000-500h-PT-cell54-flr.npy',
#  'SW3-DH3000-500h-PT-cell50-fup.npy',
#  'my_0_EL_18.09.2023-15-40-40_unknownID_ASU Minisample_SHJ5_103.npy',
#  '1920.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell37.npy',
#  'my_SW1-DH3000-500h-PT-cell50.npy',
#  'my_1869.npy',
#  '2_EL_18.09.2023-15-40-40_unknownID_ASU Minisample_SHJ5_103.npy',
#  'mx_1869.npy',
#  'mx_SW1-DH3000-2000h-PT-cell37-r180.npy',
#  'my_LG2-DH3000-1000h-PT-cell24.npy',
#  'mxy_sa19990_sub_EL_9-c01.npy',
#  'my_1855.npy',
#  'mxy_sa19976_sub_EL_9-c01.npy',
#  '0369.npy',
#  'mx_1855.npy',
#  'mx_SW3-DH3000-500h-PT-cell46.npy',
#  'my_SW2-DH3000-2000h-PT-cell59-r180.npy',
#  'SW2-DH3000-1000h-PT-cell19.npy',
#  '0194.npy',
#  'mx_sa19980_sub_EL_9-c01.npy',
#  'my_SW1-DH3000-1500h-PT-cell33-fup.npy',
#  'my_sa19991_sub_EL_9-c01.npy',
#  '1249.npy',
#  'SW2-DH3000-2000h-PT-cell54.npy',
#  'mx_SW1-DH3000-500h-PT-cell19.npy',
#  'my_0949.npy',
#  'mx_sa19966_sub_EL_9-c01.npy',
#  'mx_0949.npy',
#  'mx_1182 - Ea_TC_EVA_3_Isc (EL Image).npy',
#  'mx_sa19958_sub_EL_9-c01.npy',
#  '1275.npy',
#  'sa19961_sub_EL_9-c01.npy',
#  'SW2-DH3000-500h-PT-cell14.npy',
#  'my_1504.npy',
#  'mx_1504.npy',
#  '0_EL_18.09.2023-15-43-19_unknownID_ASU Minisample_SHJ6_106.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell44-flr.npy',
#  'my_SW3-DH3000-1000h-PT-cell37-r180.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell34.npy',
#  'mxy_sa19984_sub_EL_9-c03.npy',
#  'mx_LG2-DH3000-500h-PT-cell24.npy',
#  'mx_SW2-DH3000-1500h-PT-cell46-flr.npy',
#  'mx_SW2-DH3000-2000h-PT-cell14-flr.npy',
#  'SW3-DH3000-2000h-PT-cell50-fup.npy',
#  'mx_SW1-DH3000-2000h-PT-cell19-fup.npy',
#  'mx_SW1-DH3000-1500h-PT-cell19.npy',
#  'mx_1289.npy',
#  'mxy_SW1-DH3000-500h-PT-cell33-flr.npy',
#  '1467.npy',
#  'SW3-DH3000-1500h-PT-cell12-fup.npy',
#  'mx_SW1-DH3000-2000h-PT-cell9-flr.npy',
#  'my_SW3-DH3000-1000h-PT-cell46-fup.npy',
#  'mxy_sa19962_sub_EL_9-c03.npy',
#  'my_1289.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell9-r180.npy',
#  'my_0418.npy',
#  'mxy_0980.npy',
#  'mxy_SW3-DH3000-1000h-PT-cell46-r180.npy',
#  'my_1182 - Ea_TC_EVA_3_Isc (EL Image).npy',
#  'mx_0418.npy',
#  'mxy_1452.npy',
#  'mx_1048.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell44-fup.npy',
#  'SW1-DH3000-1000h-PT-cell15-flr.npy',
#  '0_EL_2x2_NQ-02_20230915_130525.jpg.npy',
#  'my_1048.npy',
#  'mx_2_EL_18.09.2023-15-00-34_unknownID_ASU Minisample_07_68.npy',
#  'mx_SW3-DH3000-2000h-PT-cell12.npy',
#  'sa19993_sub_EL_9-c03.npy',
#  'my_sa19985_sub_EL_9-c03.npy',
#  'mx_sa19994_sub_EL_9-c03.npy',
#  'my_sa19963_sub_EL_9-c03.npy',
#  'mxy_SW2-DH3000-1500h-PT-cell59.npy',
#  'mx_sa19972_sub_EL_9-c03.npy',
#  'mxy_SW1-DH3000-500h-PT-cell33-fup.npy',
#  'SW1-DH3000-500h-PT-cell52.npy',
#  'SW2-DH3000-1500h-PT-cell57.npy',
#  'mx_1920.npy',
#  'my_2_EL_18.09.2023-14-51-50_unknownID_ASU Minisample_05_57.npy',
#  'mx_2_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_04_48.npy',
#  'my_SW2-DH3000-1000h-PT-cell59.npy',
#  'my_1920.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell10-r180.npy',
#  'my_sa19963_sub_EL_9-c02.npy',
#  'mx_sa19972_sub_EL_9-c02.npy',
#  'sa19965_sub_EL_9-c04.npy',
#  '0220.npy',
#  'mx_sa19984_sub_EL_9-c04.npy',
#  'mx_SW2-DH3000-1500h-PT-cell54-r180.npy',
#  'mx_SW1-DH3000-500h-PT-cell9-fup.npy',
#  'sa19993_sub_EL_9-c02.npy',
#  'sa19983_sub_EL_9-c04.npy',
#  'mx_sa19994_sub_EL_9-c02.npy',
#  'my_sa19995_sub_EL_9-c04.npy',
#  'SW3-DH3000-2000h-PT-cell18.npy',
#  'mxy_1484.npy',
#  'mxy_1_EL_18.09.2023-15-53-07_unknownID_ASU Minisample_SHJ8_117.npy',
#  'my_3_EL_18.09.2023-14-45-47_unknownID_ASU Minisample_09_51.npy',
#  'mx_0343.npy',
#  'my_SW2-DH3000-2000h-PT-cell14.npy',
#  'mxy_0765.npy',
#  'SW1-DH3000-500h-PT-cell56-fup.npy',
#  'my_0343.npy',
#  'mx_SW1-DH3000-1500h-PT-cell52-r180.npy',
#  'SW1-DH3000-2000h-PT-cell9.npy',
#  'SW1-DH3000-2000h-PT-cell49-r180.npy',
#  'mx_SW3-DH3000-500h-PT-cell46-flr.npy',
#  '0591.npy',
#  'mxy_LG2-DH3000-2000h-PT-cell24-r180.npy',
#  'SW2-DH3000-1500h-PT-cell14-r180.npy',
#  'mxy_sa19962_sub_EL_9-c02.npy',
#  'my_SW1-DH3000-500h-PT-cell56-r180.npy',
#  '1300.npy',
#  'SW3-DH3000-500h-PT-cell18.npy',
#  'mxy_sa19972_sub_EL_9-c04.npy',
#  'mxy_1220 - Old TC for PID_2_rear_Isc (EL Image).npy',
#  'mx_0800.npy',
#  'my_SW1-DH3000-1000h-PT-cell33-flr.npy',
#  'mxy_sa19984_sub_EL_9-c02.npy',
#  'mxy_sa19994_sub_EL_9-c04.npy',
#  'my_0800.npy',
#  '0963.npy',
#  'mx_SW1-DH3000-2000h-PT-cell54-flr.npy',
#  'my_SW1-DH3000-1000h-PT-cell34.npy',
#  'my_0633.npy',
#  'SW1-DH3000-500h-PT-cell56-flr.npy',
#  'mxy_0215.npy',
#  '1207 - Old TC for PID_1_front_Isc (EL Image).npy',
#  'mx_SW1-DH3000-500h-PT-cell49-flr.npy',
#  'mx_0633.npy',
#  'mxy_0229.npy',
#  'my_SW3-DH3000-500h-PT-cell42-r180.npy',
#  'mx_SW2-DH3000-2000h-PT-cell59-fup.npy',
#  'my_SW1-DH3000-500h-PT-cell43-fup.npy',
#  'my_SW3-DH3000-1500h-PT-cell46-flr.npy',
#  'SW3-DH3000-1000h-PT-cell12-flr.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell43-fup.npy',
#  'mx_SW2-DH3000-2000h-PT-cell46-r180.npy',
#  'SW1-DH3000-500h-PT-cell34-flr.npy',
#  'mx_sa19979_sub_EL_9-c01.npy',
#  'mx_SW2-DH3000-1000h-PT-cell46-fup.npy',
#  'my_0021.npy',
#  'mx_0021.npy',
#  'mx_1_EL_2x2_NQ-03_20230915_125152.npy',
#  'mx_1471.npy',
#  'mx_1212 - Old TC for PID_1_rear_Isc (EL Image).jpg.npy',
#  'my_1471.npy',
#  'mx_SW1-DH3000-2000h-PT-cell33.npy',
#  'SW1-DH3000-1000h-PT-cell49.npy',
#  'my_SW1-DH3000-1500h-PT-cell52.npy',
#  '3_EL_2x2_NQ-04_20230915_130134.npy',
#  'mxy_sa19969_sub_EL_9-c01.npy',
#  'mxy_LG2-DH3000-1500h-PT-cell24.npy',
#  'mx_0_EL_2x2_NQ-01_20230915_125923.npy',
#  'my_1883.npy',
#  'SW1-DH3000-1500h-PT-cell15-fup.npy',
#  'mx_1883.npy',
#  'mxy_0177.npy',
#  'mx_SW1-DH3000-1000h-PT-cell56.npy',
#  'my_1628.npy',
#  'mxy_sa19959_sub_EL_9-c03.npy',
#  '1978.npy',
#  'mxy_sa19967_sub_EL_9-c03.npy',
#  'SW1-DH3000-2000h-PT-cell9-r180.npy',
#  'mx_1628.npy',
#  'SW3-DH3000-2000h-PT-cell46-r180.npy',
#  'mx_SW1-DH3000-1000h-PT-cell19.npy',
#  '1944.npy',
#  'mxy_1232.npy',
#  '0496.npy',
#  'mxy_sa19978_sub_EL_9-c02.npy',
#  'mxy_SW3-DH3000-1500h-PT-cell44-r180.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell34.npy',
#  'my_SW1-DH3000-500h-PT-cell15-fup.npy',
#  'mxy_3_EL_18.09.2023-15-03-23_unknownID_ASU Minisample_08_71.npy',
#  'my_SW3-DH3000-2000h-PT-cell42-flr.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell15-fup.npy',
#  'SW3-DH3000-1000h-PT-cell44-flr.npy',
#  'mx_2_EL_18.09.2023-15-34-42_unknownID_ASU Minisample_SHJ3_97.npy',
#  'mx_SW1-DH3000-2000h-PT-cell54.npy',
#  'SW2-DH3000-1000h-PT-cell57.npy',
#  'mx_1358.npy',
#  'mx_2_EL_18.09.2023-14-45-47_unknownID_ASU Minisample_09_51.npy',
#  'SW1-DH3000-1500h-PT-cell43-fup.npy',
#  'mxy_SW2-DH3000-1000h-PT-cell59.npy',
#  'my_sa19958_sub_EL_9-c03.npy',
#  'my_sa19966_sub_EL_9-c03.npy',
#  'my_1358.npy',
#  'mxy_SW3-DH3000-1000h-PT-cell50-flr.npy',
#  'sa19989_sub_EL_9-c02.npy',
#  'mx_sa19991_sub_EL_9-c03.npy',
#  'mxy_1_EL_18.09.2023-14-38-10_unknownID_ASU Minisample_02_43.npy',
#  'my_0708.npy',
#  'mx_sa19978_sub_EL_9-c04.npy',
#  'my_sa19979_sub_EL_9-c02.npy',
#  'my_sa19980_sub_EL_9-c03.npy',
#  'mx_3_EL_18.09.2023-14-51-50_unknownID_ASU Minisample_05_57.npy',
#  'mx_1191 - Ea_TC_POE_1_Isc (EL Image).npy',
#  'mx_0708.npy',
#  'mxy_1971.npy',
#  'mxy_SW2-DH3000-2000h-PT-cell14.npy',
#  'mx_SW1-DH3000-500h-PT-cell43.npy',
#  '0657.npy',
#  'my_SW2-DH3000-1500h-PT-cell46-r180.npy',
#  'SW1-DH3000-500h-PT-cell10-fup.npy',
#  'my_SW2-DH3000-500h-PT-cell54-fup.npy',
#  'mxy_sa19973_sub_EL_9-c01.npy',
#  'mx_SW1-DH3000-1500h-PT-cell50-fup.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell52.npy',
#  'mxy_sa19995_sub_EL_9-c01.npy',
#  'mxy_1145 - Ea_SHJ_POE_2_Isc (EL Image).npy',
#  'my_LG2-DH3000-1500h-PT-cell24.npy',
#  'mx_LG2-DH3000-1000h-PT-cell24-flr.npy',
#  'mxy_SW2-DH3000-500h-PT-cell57.npy',
#  'mxy_sa19970_EL_9-c02.npy',
#  '1415.npy',
#  'SW2-DH3000-500h-PT-cell54-r180.npy',
#  'mxy_2_EL_2x2_NQ-04_20230915_130134.npy',
#  '0_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_03_48.npy',
#  'my_LG2-DH3000-500h-PT-cell24-r180.npy',
#  '1429.npy',
#  'my_SW2-DH3000-1500h-PT-cell57-flr.npy',
#  'my_sa19972_sub_EL_9-c01.npy',
#  'mx_SW1-DH3000-1500h-PT-cell50-flr.npy',
#  'mx_sa19963_sub_EL_9-c01.npy',
#  'my_SW2-DH3000-500h-PT-cell54-flr.npy',
#  'mxy_SW3-DH3000-500h-PT-cell37-flr.npy',
#  'sa19982_sub_EL_9-c01.npy',
#  'my_sa19994_sub_EL_9-c01.npy',
#  'mx_sa19985_sub_EL_9-c01.npy',
#  'my_1_EL_2x2_NQ-01_20230915_125923.jpg.npy',
#  '1165.npy',
#  'my_1191 - Ea_TC_POE_1_Isc (EL Image).npy',
#  '1166 - Ea_SHJ_EVA_3_Isc (EL Image).npy',
#  'SW2-DH3000-1500h-PT-cell19.npy',
#  'my_SW2-DH3000-1500h-PT-cell57-fup.npy',
#  'mxy_1_EL_18.09.2023-14-55-55_unknownID_ASU Minisample_06_62.npy',
#  '1159.npy',
#  'mxy_0924.npy',
#  'SW3-DH3000-500h-PT-cell42-flr.npy',
#  '0252.npy',
#  '0_EL_18.09.2023-14-55-55_unknownID_ASU Minisample_06_62.npy',
#  'my_0_EL_2x2_NQ-04_20230915_130134.npy',
#  'SW3-DH3000-2000h-PT-cell42.npy',
#  'mx_SW1-DH3000-500h-PT-cell52-fup.npy',
#  'SW3-DH3000-1500h-PT-cell44-fup.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell54-r180.npy',
#  'mxy_2128.npy',
#  'mxy_2114.npy',
#  'SW1-DH3000-1000h-PT-cell43-fup.npy',
#  'my_0872.npy',
#  '0722.npy',
#  'mxy_SW2-DH3000-500h-PT-cell46-flr.npy',
#  'mx_SW1-DH3000-1500h-PT-cell56.npy',
#  'mx_0872.npy',
#  'mxy_1_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_03_48.npy',
#  'my_SW1-DH3000-2000h-PT-cell37.npy',
#  'mx_SW1-DH3000-500h-PT-cell52-flr.npy',
#  'my_SW2-DH3000-500h-PT-cell19-flr.npy',
#  'SW3-DH3000-500h-PT-cell44-r180.npy',
#  'mx_2_EL_18.09.2023-15-31-57_unknownID_ASU Minisample_SHJ2_94.npy',
#  'mx_SW1-DH3000-1000h-PT-cell19-r180.npy',
#  'my_SW3-DH3000-2000h-PT-cell50-r180.npy',
#  'mxy_1804.npy',
#  'my_SW2-DH3000-500h-PT-cell59.npy',
#  'mxy_sa19970_EL_9-c03.npy',
#  'SW1-DH3000-500h-PT-cell50-r180.npy',
#  'mxy_LG2-DH3000-1000h-PT-cell24.npy',
#  'my_2042.npy',
#  'SW1-DH3000-1500h-PT-cell49.npy',
#  'SW1-DH3000-1000h-PT-cell43-flr.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell12-fup.npy',
#  'mx_2042.npy',
#  'mxy_SW3-DH3000-1500h-PT-cell50-fup.npy',
#  'my_3_EL_18.09.2023-15-00-34_unknownID_ASU Minisample_07_68.npy',
#  'my_SW2-DH3000-1000h-PT-cell57-fup.npy',
#  'mxy_1794.npy',
#  'mx_LG2-DH3000-1500h-PT-cell24-fup.npy',
#  'sa19986_sub_EL_9-c04.npy',
#  'my_sa19990_sub_EL_9-c04.npy',
#  'mx_sa19991_sub_EL_9-c02.npy',
#  'my_sa19980_sub_EL_9-c02.npy',
#  '1234 - Old TC for PID_Rear_4_Isc (EL Image).npy',
#  'my_sa19979_sub_EL_9-c03.npy',
#  'my_sa19976_sub_EL_9-c04.npy',
#  'mx_sa19959_sub_EL_9-c04.npy',
#  'my_sa19958_sub_EL_9-c02.npy',
#  'mx_0053.npy',
#  'mx_SW2-DH3000-1500h-PT-cell59-r180.npy',
#  'sa19960_sub_EL_9-c04.npy',
#  'sa19989_sub_EL_9-c03.npy',
#  'my_SW2-DH3000-1500h-PT-cell59.npy',
#  '0_EL_18.09.2023-14-38-10_unknownID_ASU Minisample_02_43.npy',
#  'my_sa19966_sub_EL_9-c02.npy',
#  'mx_sa19967_sub_EL_9-c04.npy',
#  'my_0053.npy',
#  'mxy_SW3-DH3000-500h-PT-cell18-flr.npy',
#  'my_0_EL_18.09.2023-15-53-07_unknownID_ASU Minisample_SHJ8_117.npy',
#  '2_EL_18.09.2023-15-03-23_unknownID_ASU Minisample_08_71.npy',
#  'SW1-DH3000-1000h-PT-cell10-r180.npy',
#  'mx_SW2-DH3000-1000h-PT-cell57-r180.npy',
#  'my_SW3-DH3000-1500h-PT-cell42-r180.npy',
#  'my_SW1-DH3000-2000h-PT-cell37-fup.npy',
#  '0440.npy',
#  '1_EL_18.09.2023-15-37-22_unknownID_ASU Minisample_SHJ4_100.npy',
#  'my_SW1-DH3000-1500h-PT-cell34.npy',
#  'SW1-DH3000-500h-PT-cell19-r180.npy',
#  'mxy_sa19991_sub_EL_9-c04.npy',
#  'mxy_SW1-DH3000-500h-PT-cell10.npy',
#  'mxy_0139.npy',
#  'my_SW3-DH3000-2000h-PT-cell18-r180.npy',
#  'mxy_sa19978_sub_EL_9-c03.npy',
#  'mx_SW1-DH3000-1000h-PT-cell50-r180.npy',
#  'mx_SW1-DH3000-1000h-PT-cell50-fup.npy',
#  'mxy_sa19959_sub_EL_9-c02.npy',
#  'mxy_sa19967_sub_EL_9-c02.npy',
#  'mxy_SW1-DH3000-1000h-PT-cell49-r180.npy',
#  'my_SW1-DH3000-500h-PT-cell37.npy',
#  'SW3-DH3000-1000h-PT-cell50-r180.npy',
#  'my_1159.npy',
#  'SW1-DH3000-500h-PT-cell19-fup.npy',
#  'SW1-DH3000-1500h-PT-cell9-flr.npy',
#  'mx_1159.npy',
#  'mxy_sa19978_sub_EL_9-c01.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell52.npy',
#  'mxy_1543.npy',
#  'my_1165.npy',
#  'my_3_EL_18.09.2023-15-37-22_unknownID_ASU Minisample_SHJ4_100.npy',
#  'mx_SW2-DH3000-1500h-PT-cell54-flr.npy',
#  'mx_1165.npy',
#  'mxy_0891.npy',
#  'my_SW1-DH3000-1500h-PT-cell43-fup.npy',
#  'mxy_SW3-DH3000-2000h-PT-cell46-flr.npy',
#  'mx_SW1-DH3000-2000h-PT-cell43.npy',
#  'mx_SW1-DH3000-1500h-PT-cell49-flr.npy',
#  'mx_1429.npy',
#  'sa19989_sub_EL_9-c01.npy',
#  'SW3-DH3000-2000h-PT-cell42-flr.npy',
#  'my_SW3-DH3000-1000h-PT-cell44-flr.npy',
#  'my_1429.npy',
#  'mx_3_EL_2x2_NQ-02_20230915_130525.jpg.npy',
#  'mx_1415.npy',
#  'mx_SW2-DH3000-1500h-PT-cell54-fup.npy',
#  'my_1415.npy',
#  'my_sa19979_sub_EL_9-c01.npy',
#  'mx_SW1-DH3000-500h-PT-cell37-r180.npy',
#  'my_SW1-DH3000-2000h-PT-cell9-r180.npy',
#  'mx_SW1-DH3000-500h-PT-cell54.npy',
#  'my_1155 - Ea_SHJ_POE_5_Isc (EL Image).npy',
#  'SW2-DH3000-500h-PT-cell59.npy',
#  'mxy_sa19963_sub_EL_9-c04.npy',
#  'my_0657.npy',
#  'my_SW1-DH3000-1000h-PT-cell50.npy',
#  'mxy_sa19973_sub_EL_9-c02.npy',
#  'mx_0657.npy',
#  'mxy_sa19970_EL_9-c01.npy',
#  'SW2-DH3000-1500h-PT-cell57-fup.npy',
#  'mxy_SW2-DH3000-500h-PT-cell54.npy',
#  'mxy_sa19985_sub_EL_9-c04.npy',
#  'my_SW1-DH3000-2000h-PT-cell10-r180.npy',
#  'mxy_sa19995_sub_EL_9-c02.npy',
#  'mxy_1302 - NICE TOPCon 2 Front Enapsulated (EL Image).npy',
#  '0708.npy',
#  'my_LG2-DH3000-2000h-PT-cell24-r180.npy',
#  'mx_SW2-DH3000-500h-PT-cell57-fup.npy',
#  '1358.npy',
#  'mx_SW2-DH3000-1000h-PT-cell19-fup.npy',
#  'mxy_SW1-DH3000-500h-PT-cell43-fup.npy',
#  'SW3-DH3000-1000h-PT-cell18-r180.npy',
#  'my_SW2-DH3000-500h-PT-cell54-r180.npy',
#  'mx_0_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_04_48.npy',
#  'sa19974_sub_EL_9-c04.npy',
#  'mx_sa19963_sub_EL_9-c02.npy',
#  'my_sa19972_sub_EL_9-c02.npy',
#  'LG2-DH3000-500h-PT-cell24-r180.npy',
#  'my_sa19984_sub_EL_9-c04.npy',
#  'sa19992_sub_EL_9-c04.npy',
#  'my_sa19994_sub_EL_9-c02.npy',
#  'mx_sa19995_sub_EL_9-c04.npy',
#  'my_1_EL_18.09.2023-14-45-47_unknownID_ASU Minisample_09_51.npy',
#  'SW2-DH3000-1500h-PT-cell57-flr.npy',
#  'SW1-DH3000-500h-PT-cell37.npy',
#  'my_0496.npy',
#  'mx_SW2-DH3000-500h-PT-cell57-flr.npy',
#  'mx_1944.npy',
#  'mx_0496.npy',
#  'mxy_1224 - Old TC for PID_3_front_Isc (EL Image).jpg.npy',
#  'my_1944.npy',
#  '1152 - Ea_SHJ_POE_4_Isc (EL Image).npy',
#  'mx_1978.npy',
#  '1628.npy',
#  'my_1978.npy',
#  'my_SW1-DH3000-500h-PT-cell50-r180.npy',
#  'mxy_SW3-DH3000-1000h-PT-cell37-r180.npy',
#  'my_SW1-DH3000-1000h-PT-cell43-flr.npy',
#  'mx_2_EL_2x2_NQ-03_20230915_125152.npy',
#  'mx_0_EL_18.09.2023-15-00-34_unknownID_ASU Minisample_07_68.npy',
#  'mx_1207 - Old TC for PID_1_front_Isc (EL Image).npy',
#  'mx_SW1-DH3000-2000h-PT-cell34-flr.npy',
#  'mx_sa19985_sub_EL_9-c03.npy',
#  'my_sa19994_sub_EL_9-c03.npy',
#  'sa19982_sub_EL_9-c03.npy',
#  'mx_sa19963_sub_EL_9-c03.npy',
#  'my_SW3-DH3000-500h-PT-cell44-r180.npy',
#  'my_sa19972_sub_EL_9-c03.npy',
#  'my_0440.npy',
#  'SW3-DH3000-1000h-PT-cell18.npy',
#  'mx_0440.npy',
#  '0053.npy',
#  'my_SW3-DH3000-1000h-PT-cell46-r180.npy',
#  'mxy_1_EL_18.09.2023-15-40-40_unknownID_ASU Minisample_SHJ5_103.npy',
#  'mx_3_EL_2x2_NQ-01_20230915_125923.npy',
#  'SW1-DH3000-1500h-PT-cell15-r180.npy',
#  'my_SW1-DH3000-1000h-PT-cell43-fup.npy',
#  'mx_2_EL_18.09.2023-15-40-40_unknownID_ASU Minisample_SHJ5_103.npy',
#  'mxy_sa19995_sub_EL_9-c03.npy',
#  'mx_SW2-DH3000-1000h-PT-cell54-flr.npy',
#  'mx_SW1-DH3000-1000h-PT-cell49-fup.npy',
#  '0_EL_2x2_NQ-04_20230915_130134.npy',
#  'mxy_SW1-DH3000-1500h-PT-cell50.npy',
#  'my_SW3-DH3000-1500h-PT-cell44-fup.npy',
#  '0_EL_2x2_NQ-03_20230915_125152.jpg.npy',
#  'mx_SW1-DH3000-1500h-PT-cell54-r180.npy',
#  'mxy_0516.npy',
#  'mxy_sa19973_sub_EL_9-c03.npy',
#  'mx_SW3-DH3000-500h-PT-cell44-flr.npy',
#  'mx_SW2-DH3000-1500h-PT-cell19-flr.npy',
#  'SW3-DH3000-1500h-PT-cell42.npy',
#  '2042.npy',
#  'my_SW1-DH3000-500h-PT-cell33-flr.npy',
#  'mx_SW1-DH3000-2000h-PT-cell56-fup.npy',
#  'my_sa19980_sub_EL_9-c01.npy',
#  'SW1-DH3000-2000h-PT-cell37-fup.npy',
#  'mx_sa19991_sub_EL_9-c01.npy',
#  'mx_0722.npy',
#  'my_sa19966_sub_EL_9-c01.npy',
#  'mxy_0304.npy',
#  'my_sa19958_sub_EL_9-c01.npy',
#  'my_SW1-DH3000-500h-PT-cell19-r180.npy',
#  '0872.npy',
#  'my_0722.npy',
#  'SW1-DH3000-1000h-PT-cell10.npy',
#  'mxy_1595.npy',
#  'my_SW1-DH3000-500h-PT-cell33-fup.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell33-fup.npy',
#  'mxy_1217 - Old TC for PID_2_front_Isc (EL Image).npy',
#  'mx_SW3-DH3000-500h-PT-cell44-fup.npy',
#  'mxy_SW2-DH3000-2000h-PT-cell59-r180.npy',
#  'mxy_3_EL_18.09.2023-15-43-19_unknownID_ASU Minisample_SHJ6_106.npy',
#  'mx_SW1-DH3000-1000h-PT-cell33.npy',
#  'mxy_0648.npy',
#  'SW2-DH3000-1000h-PT-cell57-fup.npy',
#  'mx_0_EL_18.09.2023-15-43-19_unknownID_ASU Minisample_SHJ6_106.npy',
#  'my_0252.npy',
#  'mxy_0674.npy',
#  'mxy_sa19959_sub_EL_9-c01.npy',
#  'mxy_2077.npy',
#  'mx_0252.npy',
#  'mxy_sa19991_sub_EL_9-c03.npy',
#  'mxy_sa19978_sub_EL_9-c04.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell43.npy',
#  'mxy_0102.npy',
#  'mx_0_EL_18.09.2023-15-31-57_unknownID_ASU Minisample_SHJ2_94.npy',
#  'my_0_EL_18.09.2023-15-37-22_unknownID_ASU Minisample_SHJ4_100.npy',
#  'mx_1_EL_18.09.2023-14-42-47_unknownID_ASU Minisample_04_48.npy',
#  'my_1_EL_18.09.2023-14-51-50_unknownID_ASU Minisample_05_57.npy',
#  'mxy_SW1-DH3000-500h-PT-cell49-r180.npy',
#  'mx_SW1-DH3000-2000h-PT-cell52.npy',
#  'my_0_EL_18.09.2023-14-45-47_unknownID_ASU Minisample_09_51.npy',
#  'my_SW1-DH3000-1500h-PT-cell33.npy',
#  'mx_0068.npy',
#  'my_SW1-DH3000-1000h-PT-cell10-r180.npy',
#  'my_sa19990_sub_EL_9-c03.npy',
#  'mxy_LG2-DH3000-2000h-PT-cell24-fup.npy',
#  'my_0068.npy',
#  'sa19986_sub_EL_9-c03.npy',
#  'mx_SW3-DH3000-500h-PT-cell18-flr.npy',
#  'SW3-DH3000-1500h-PT-cell42-r180.npy',
#  'my_sa19979_sub_EL_9-c04.npy',
#  'mx_sa19978_sub_EL_9-c02.npy',
#  'sa19960_sub_EL_9-c03.npy',
#  'my_sa19976_sub_EL_9-c03.npy',
#  'mx_sa19959_sub_EL_9-c03.npy',
#  'mx_sa19967_sub_EL_9-c03.npy',
#  'mx_1188 - Ea_TC_EVA_Isc (EL Image).npy',
#  'sa19989_sub_EL_9-c04.npy',
#  '1217 - Old TC for PID_2_front_Isc (EL Image).npy',
#  'mxy_0472.npy',
#  '1302 - NICE TOPCon 2 Front Enapsulated (EL Image).npy',
#  'SW3-DH3000-1500h-PT-cell46.npy',
#  'SW3-DH3000-2000h-PT-cell18-r180.npy',
#  '1_EL_18.09.2023-15-53-07_unknownID_ASU Minisample_SHJ8_117.npy',
#  'my_SW1-DH3000-1500h-PT-cell52-fup.npy',
#  'my_SW1-DH3000-2000h-PT-cell10-fup.npy',
#  'my_2079.npy',
#  'mxy_sa19970_EL_9-c04.npy',
#  'mx_2079.npy',
#  'SW2-DH3000-1500h-PT-cell46-flr.npy',
#  'mxy_sa19985_sub_EL_9-c01.npy',
#  'SW2-DH3000-2000h-PT-cell14-flr.npy',
#  'SW1-DH3000-2000h-PT-cell19-fup.npy',
#  'mx_SW3-DH3000-2000h-PT-cell50-fup.npy',
#  'mxy_sa19963_sub_EL_9-c01.npy',
#  'mx_SW3-DH3000-1500h-PT-cell12-fup.npy',
#  '0916.npy',
#  'my_SW3-DH3000-500h-PT-cell12-fup.npy',
#  'my_0875.npy',
#  'mxy_SW1-DH3000-500h-PT-cell52-flr.npy',
#  'my_SW3-DH3000-1000h-PT-cell37-fup.npy',
#  'mx_0875.npy',
#  '2126.npy',
#  'mx_SW2-DH3000-500h-PT-cell46-flr.npy',
#  'mx_sa19995_sub_EL_9-c01.npy',
#  'my_sa19984_sub_EL_9-c01.npy',
#  'sa19992_sub_EL_9-c01.npy',
#  'SW3-DH3000-2000h-PT-cell50-r180.npy',
#  'my_0336.npy',
#  'mxy_0710.npy',
#  'mx_sa19973_sub_EL_9-c01.npy',
#  'mx_0336.npy',
#  'sa19974_sub_EL_9-c01.npy',
#  'my_sa19962_sub_EL_9-c01.npy',
#  'mxy_SW1-DH3000-500h-PT-cell52-fup.npy',
#  'mxy_0923.npy',
#  '0255.npy',
#  'SW2-DH3000-500h-PT-cell59-fup.npy',
#  'mx_SW1-DH3000-1000h-PT-cell15-flr.npy',
#  'my_SW3-DH3000-1500h-PT-cell18-flr.npy',
#  'SW3-DH3000-2000h-PT-cell44.npy',
#  'mxy_SW2-DH3000-1000h-PT-cell59-r180.npy',
#  'SW2-DH3000-500h-PT-cell14-flr.npy',
#  'my_SW1-DH3000-500h-PT-cell50-flr.npy',
#  'mx_SW3-DH3000-500h-PT-cell37-flr.npy',
#  'my_LG2-DH3000-500h-PT-cell24.npy',
#  'mxy_SW1-DH3000-2000h-PT-cell50-flr.npy',
#  'mxy_1427.npy',
#  '0283.npy',
#  'SW1-DH3000-500h-PT-cell37-fup.npy',
#  'SW1-DH3000-2000h-PT-cell54-flr.npy',
#  'my_SW1-DH3000-1000h-PT-cell52-flr.npy',
#  'mx_SW2-DH3000-2000h-PT-cell14-r180.npy',
#  'mxy_2_EL_18.09.2023-15-40-40_unknownID_ASU Minisample_SHJ5_103.npy',
#  'SW3-DH3000-500h-PT-cell50.npy',
#  ...]

# %%
class_tally = {k: 0 for k in category_mapping.values()}

mask_data_list = []

for f in files:
    mask_path = os.path.join(mask_folder, f)
    if not os.path.exists(mask_path):
        print(f"Mask file {mask_path} does not exist. Skipping.")
        continue

    mask_data = np.load(mask_path, allow_pickle=True)
    mask_data_list.append(mask_data)

    for i, class_name in enumerate(categories_list):
        if np.any(mask_data[i]):
            class_tally[class_name] += 1

print("Class Tally:")
for class_name, count in class_tally.items():
    print(f"{class_name}: {count}")
# Out:
# Class Tally:
# empty: 0
# dark: 364
# busbar: 2340
# crack: 1688
# non-cell: 2340

# %%
"""
mask_data_list: list of all the 5-channeled masks
mask_data_list[0]: 5-channeled mask for image. 400x400x5
mask_data_list[0][0]: 1 channel of the mask of an image. 400x400
mask_data_list[0][0][0]: 1 dimension of 1 channel of the mask of an image. 400
"""
# Out:
# '\nmask_data_list: list of all the 5-channeled masks\nmask_data_list[0]: 5-channeled mask for image. 400x400x5\nmask_data_list[0][0]: 1 channel of the mask of an image. 400x400\nmask_data_list[0][0][0]: 1 dimension of 1 channel of the mask of an image. 400\n'

# %%
# Calculate the cardinality of the dataset
num_images = len(mask_data_list)
sum_labels_per_pixel = 0
for mask_data in mask_data_list:
    pixels_in_image = mask_data[1].size
    labels_in_image = np.sum(mask_data[1:])
    labels_per_pixel = labels_in_image / pixels_in_image
    sum_labels_per_pixel += labels_per_pixel

cardinality = sum_labels_per_pixel / n_masks
# cardinality = (sum_labels_per_pixel + n_masks) / n_masks

print(f"Cardinality: {cardinality}")
# Out:
# Cardinality: 0.24049954329816203

# %%
# Calculate the density of the dataset
num_labels = 0
for mask_data in mask_data_list:
    labels_in_image = np.sum(mask_data[1:])
    num_labels += labels_in_image

density = cardinality / num_labels
# density = cardinality / (mask_data[1][1].size * num_images)

print(f"Density: {density}")
# Out:
# Density: 1.9699911319772553e-09

# %%
# Calculate the percentage of instances with only one active label
total_single_label_instances = 0
for mask_data in mask_data_list:
    pixel_wise_label_sums = np.sum(mask_data[1:], axis=0)
    single_label_instances = np.sum(pixel_wise_label_sums == 1)
    total_single_label_instances += single_label_instances

num_labels = 0
for mask_data in mask_data_list:
    labels_in_image = np.sum(mask_data[1:])
    num_labels += labels_in_image

final_single_label_instances = total_single_label_instances / num_labels
final_single_label_instances *= 100

# single_label_instances = np.mean([np.sum(mask_data) == 1 for mask_data in mask_data_list])
print(f"Single label instances: {final_single_label_instances}")
# Out:
# Single label instances: 95.23864116519634

# %%
total_imgs = class_tally["non-cell"]

for id, category in enumerate(list(category_mapping.values())[1:]):
    num_images_with_categoy = class_tally[category]
    freq = num_images_with_categoy / total_imgs
    print(f"{(freq * 100):.3f}% of images include Class {id} ({category})")


# Calculate the frequency of each label and distinct label set
# label_frequency = Counter([label for mask_data in mask_data_list for label in np.where(mask_data)[0]])

# print("Label Frequency:")
# for label, frequency in label_frequency.items():
# print(f"{category_mapping[label]}: {frequency}")
# Out:
# 15.556% of images include Class 0 (dark)
# 100.000% of images include Class 1 (busbar)
# 72.137% of images include Class 2 (crack)
# 100.000% of images include Class 3 (non-cell)

# %%
# Calculate the frequency of each label
# Create an empty list to store all channel indices
all_channels = []

# Iterate through each mask in the list
for mask_data in mask_data_list:
    # Get the channel indices (first array from np.where)
    channel_indices = np.where(mask_data)[0]
    # Add these indices to our list
    all_channels.extend(channel_indices)
# Count the frequency of each channel
label_frequency = Counter(all_channels)

# Calculate the total number of pixels
total_pixels = mask_data_list[0][0].size * num_images

# Calculate the percentage of pixels that are each class
for label, frequency in label_frequency.items():
    print(f"{category_mapping[label]}: {(frequency / total_pixels) * 100:.3f}%")
# Out:
# busbar: 20.259%
# crack: 3.505%
# non-cell: 7.813%
# dark: 1.031%

# %%
label_frequency
# Out:
# Counter({np.int64(2): 75849800,
#          np.int64(4): 29251268,
#          np.int64(3): 13121664,
#          np.int64(1): 3858804})

# %%
# Calculate the imbalance ratio for each label
max_frequency = max(label_frequency.values())

imbalance_ratio = {}

for label, frequency in label_frequency.items():
    imbalance_ratio[label] = frequency / max_frequency


# Print the imbalance ratio for each label
for label, ratio in imbalance_ratio.items():
    print(f"{category_mapping[label]}: {ratio}")
# Out:
# busbar: 1.0
# crack: 0.1729953671598343
# non-cell: 0.3856472660442084
# dark: 0.050874280485907676

# %%
# Calculate the mean imbalance ratio
mean_imbalance_ratio = np.mean(list(imbalance_ratio.values()))
print(f"Mean imbalance ratio: {mean_imbalance_ratio}")
# Out:
# Mean imbalance ratio: 0.40237922842248763
