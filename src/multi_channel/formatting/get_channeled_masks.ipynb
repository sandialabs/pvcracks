# %% [markdown]
# # setup

# %%
from torch.utils.data import DataLoader
import json
import numpy as np
import base64
import zlib
import os
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import zlib, base64
from skimage.io import imread
import os
import re
import sys
import cv2 as cv
import torch
import itertools

# %%
# root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Fresh_ASU/"
# new_root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_ASU/"

# root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/CWRU_Dupont_Mono_ContinuousCracks/"
# new_root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_CWRU_Dupont/"

# root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Fresh_CWRU_SunEdison/"
# new_root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_CWRU_SunEdison/"

root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Fresh_LBNL/"
new_root = "/Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/"

img_folder = root + "img/original/"
mask_folder = root + "ann_json/"

# image_file_extension = "tiff"
image_file_extension = "jpg"

category_mapping = {0: "empty", 1: "dark", 2: "busbar", 3: "crack", 4: "non-cell"}
categories_list = list(category_mapping.values())

# %%
files = [c for c in os.listdir(mask_folder)]

regex_string = r"(.+)\." + image_file_extension + r"\.json"

n_masks = [re.search(regex_string, f).group(1) for f in files]

# %% [markdown]
# -----

# %% [markdown]
# # conversion code

# %%
def convert_json_to_multihot(json_file_path, image):
    """
    Converts a JSON mask file into a multi-hot encoded NumPy array file.

    Parameters:
      json_file_path: Path to the JSON file containing the annotations.
      output_file_path: Path to save the resulting .npy multi-hot encoded mask.
      mapping: A dict mapping classTitle strings (from JSON) to channel indices.

    The resulting NumPy array will have shape (5, height, width) where each channel
    corresponds to one class in your segmentation task.
    """
    # Load JSON data
    with open(json_file_path, "r") as f:
        data = json.load(f)

    # Get image dimensions from the JSON
    height = data["size"]["height"]
    width = data["size"]["width"]

    # Create an empty multi-hot mask with 5 channels.
    # Channels: 0 = empty, 1 = dark, 2 = busbar, 3 = crack, 4 = non-cell.
    multi_hot = np.zeros((5, height, width), dtype=np.uint8)

    try:
        objects = data["objects"]
    except KeyError:
        objects = data["annotation"]["objects"]

    for obj in objects:
        if obj["geometryType"] == "bitmap":
            code = obj["bitmap"]["data"]
            origin = obj["bitmap"]["origin"]

            z = zlib.decompress(base64.b64decode(code))
            n = np.frombuffer(z, np.uint8)
            mask = cv.imdecode(n, cv.IMREAD_UNCHANGED)[:, :, 3].astype(bool)

            # This is some unfortunate maneuvering to address the fact that
            # bitmap annotations do not usually come in the same size as the
            # image from which they were labeled, and so it is necessary to
            # situate the annotation in an otherwise empty array that is the
            # same size as the image

            mask_center = np.array([mask.shape[1] / 2, mask.shape[0] / 2])
            mask_center += origin
            up = np.zeros((origin[1], mask.shape[1]))
            mask2 = np.vstack((up, mask))
            left = np.zeros((mask2.shape[0], origin[0]))
            mask3 = np.hstack((left, mask2))
            down = np.zeros((image.shape[0] - mask3.shape[0], mask3.shape[1]))
            mask4 = np.vstack((mask3, down))
            right = np.zeros((mask4.shape[0], image.shape[1] - mask4.shape[1]))
            mask5 = np.hstack((mask4, right)).astype(bool)

        elif obj["geometryType"] == "rectangle":
            # Handle rectangle masks
            points = obj["points"]["exterior"]
            x1, y1 = points[0]
            x2, y2 = points[1]

            mask5 = np.zeros(image.shape[:-1]).astype(bool)
            mask5[y1:y2, x1:x2] = True

        for idx, category in enumerate(categories_list):
            if category in obj["classTitle"].lower():
                # print(f"Adding mask for category: {category} at idx {idx}")
                # [print(f"Multi-hot at idx 4 before logical or: {multi_hot[idx]}") if idx == 4 else None]
                multi_hot[idx] = np.logical_or(multi_hot[idx], mask5).astype(bool)
                # [print(f"Multi-hot at idx 4 after logical or: {multi_hot[idx]}") if idx == 4 else None]

    return multi_hot

# %% [markdown]
# ---

# %% [markdown]
# ## viz stuff

# %%
def stack_masks(
    multihot, image, order=[4, 3, 2, 1, 0], mapping={0: 1, 1: 2, 2: 3, 3: 4, 4: 5}
):
    # Stack the four n_x by n_y feature arrays
    all_masks = torch.dstack([torch.tensor(v) for v in multihot]).permute(2, 0, 1)

    new_tensor = torch.zeros(
        [all_masks.shape[1], all_masks.shape[2]], dtype=torch.float64
    )

    for i, j in itertools.product(range(image.shape[0]), range(image.shape[1])):
        if all_masks[order[0], i, j]:
            val = mapping[order[0]]
        elif all_masks[order[1], i, j]:
            val = mapping[order[1]]
        elif all_masks[order[2], i, j]:
            val = mapping[order[2]]
        elif all_masks[order[3], i, j]:
            val = mapping[order[3]]
        else:
            val = 0

        new_tensor[i, j] = val

    return new_tensor

# %%
def plot_and_show_labels(cracks_mask):
    fig, ax = plt.subplots()

    clim = (0, 5)
    ax.imshow(cracks_mask, clim=clim, interpolation="None")

    # Do legend
    cmap = mpl.colormaps["viridis"].resampled(5)  # define the colormap
    cmaplist = [cmap(i) for i in range(5)]
    handles, labels = ax.get_legend_handles_labels()

    for c, classlabel in zip(
        cmaplist, [f"({k}) {v}" for k, v in category_mapping.items()]
    ):
        patch = mpatches.Patch(color=c, label=classlabel, ec="k")
        handles.append(patch)
    ax.legend(handles=handles, fontsize="x-small")

    ax.axis("off")

# %%
def inference_and_show(img, gt_mask):
    fig, ax = plt.subplots(ncols=5, nrows=2, figsize=(10, 10), layout="compressed")

    ax[0, 0].imshow(img, cmap="gray", interpolation="None")
    ax[0, 0].axis("off")
    ax[0, 0].set_title("(a) EL image", fontsize="xx-large")
    ##
    for i in range(5):
        ax[1, i].imshow(gt_mask[i], cmap="viridis", interpolation="None")
        ax[1, i].axis("off")
        ax[1, i].set_title(f"({i}) {category_mapping[i]} activation")

# %% [markdown]
# ------
#
# # Converting all masks

# %%
for index, n in enumerate(n_masks):
    mask_path = os.path.join(mask_folder, f"{n}.{image_file_extension}.json")
    img_path = os.path.join(img_folder, f"{n}.{image_file_extension}")

    image = imread(img_path)

    multihot = convert_json_to_multihot(mask_path, image)

    output_file_path = new_root + "ann/channeled/" + f"{n}.npy"
    np.save(output_file_path, multihot)

    print(f"Saved {index + 1}/{len(n_masks)}: {output_file_path}")
# Out:
# Saved 1/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1578.npy
# Saved 2/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0722.npy
# Saved 3/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1471.npy
# Saved 4/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0336.npy
# Saved 5/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0496.npy
# Saved 6/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/2021.npy
# Saved 7/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0472.npy
# Saved 8/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1275.npy
# Saved 9/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1628.npy
# Saved 10/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/2128.npy
# Saved 11/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1944.npy
# Saved 12/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1804.npy
# Saved 13/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1938.npy
# Saved 14/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1300.npy
# Saved 15/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1654.npy
# Saved 16/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0053.npy
# Saved 17/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1971.npy
# Saved 18/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1159.npy
# Saved 19/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1504.npy
# Saved 20/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0657.npy
# Saved 21/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0229.npy
# Saved 22/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1073.npy
# Saved 23/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0674.npy
# Saved 24/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1467.npy
# Saved 25/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0369.npy
# Saved 26/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0179.npy
# Saved 27/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1097.npy
# Saved 28/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1737.npy
# Saved 29/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/2002.npy
# Saved 30/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0558.npy
# Saved 31/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0418.npy
# Saved 32/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0980.npy
# Saved 33/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0255.npy
# Saved 34/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1452.npy
# Saved 35/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1046.npy
# Saved 36/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1429.npy
# Saved 37/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1134.npy
# Saved 38/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1460.npy
# Saved 39/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1484.npy
# Saved 40/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0283.npy
# Saved 41/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/2079.npy
# Saved 42/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1090.npy
# Saved 43/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1358.npy
# Saved 44/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0102.npy
# Saved 45/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1869.npy
# Saved 46/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0516.npy
# Saved 47/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0987.npy
# Saved 48/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1820.npy
# Saved 49/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0252.npy
# Saved 50/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1455.npy
# Saved 51/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0963.npy
# Saved 52/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0800.npy
# Saved 53/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1943.npy
# Saved 54/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0440.npy
# Saved 55/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1976.npy
# Saved 56/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0304.npy
# Saved 57/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0710.npy
# Saved 58/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0634.npy
# Saved 59/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0194.npy
# Saved 60/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0220.npy
# Saved 61/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1427.npy
# Saved 62/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0774.npy
# Saved 63/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0139.npy
# Saved 64/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1852.npy
# Saved 65/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0699.npy
# Saved 66/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/2077.npy
# Saved 67/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/2042.npy
# Saved 68/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1867.npy
# Saved 69/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1883.npy
# Saved 70/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0215.npy
# Saved 71/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0924.npy
# Saved 72/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0648.npy
# Saved 73/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0708.npy
# Saved 74/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0601.npy
# Saved 75/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1298.npy
# Saved 76/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0762.npy
# Saved 77/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1165.npy
# Saved 78/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0392.npy
# Saved 79/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1595.npy
# Saved 80/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1904.npy
# Saved 81/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1668.npy
# Saved 82/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1235.npy
# Saved 83/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0026.npy
# Saved 84/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1249.npy
# Saved 85/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/2114.npy
# Saved 86/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1978.npy
# Saved 87/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1200.npy
# Saved 88/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1931.npy
# Saved 89/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1544.npy
# Saved 90/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0343.npy
# Saved 91/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0872.npy
# Saved 92/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0591.npy
# Saved 93/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0809.npy
# Saved 94/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0765.npy
# Saved 95/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0949.npy
# Saved 96/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1232.npy
# Saved 97/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1592.npy
# Saved 98/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0068.npy
# Saved 99/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0021.npy
# Saved 100/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/2126.npy
# Saved 101/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1613.npy
# Saved 102/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0540.npy
# Saved 103/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0891.npy
# Saved 104/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0875.npy
# Saved 105/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1543.npy
# Saved 106/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1157.npy
# Saved 107/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1794.npy
# Saved 108/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0633.npy
# Saved 109/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1289.npy
# Saved 110/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1529.npy
# Saved 111/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0916.npy
# Saved 112/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0563.npy
# Saved 113/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1855.npy
# Saved 114/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0177.npy
# Saved 115/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1318.npy
# Saved 116/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1920.npy
# Saved 117/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0556.npy
# Saved 118/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/0923.npy
# Saved 119/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1048.npy
# Saved 120/120: /Users/ojas/Desktop/saj/SANDIA/pvcracks_data/Channeled_LBNL/ann/channeled/1415.npy

# %%
stacked = stack_masks(multihot, image)

plot_and_show_labels(stacked)

inference_and_show(image, multihot)
